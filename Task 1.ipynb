# %% [markdown]
# **<div align="center">ML ASSIGNMENT 1</div>**
#
# **<div align="center">Group - The Data Traffickers</div>**
#
# <div align="center">Vansh Kumar (23110351)</div>
#
# <div align="center">Aditya Jain (23110016)</div>
#
# <div align="center">Soham Shrivastava (23110315)</div>
#
# <div align="center">Mehta Kushal (23110205)</div>

# %% [markdown]
# **Task 1 : Exploratory Data Analysis (EDA) [3 marks]**
# **Preprocessing Done**
# **Combined Folder Created**
# **Received Test and Train Data for 6 Activities - Laying, Sitting, Standing, Walking, Walking Downstairs, Walking Upstairs**

# %% [markdown]
# Question 1: Plot the waveform for one sample data from each activity class. Are you able to see any difference/similarities between the activities? You can plot a subplot having 6 columns to show differences/similarities between the activities. Do you think the model will be able to classify the activities based on the data? [0.5 marks]

# %%
import numpy as np
import matplotlib.pyplot as plt

fig,axs=plt.subplots(3,2,figsize=(12, 18))

def load_data(file_path): #Reads data from the file
    return np.loadtxt(file_path, delimiter=',', skiprows=1, max_rows=500) #delimiter tells that data is seperated by comma
#Skip the first row
#Loads only 500 rows of data

# Laying
data=load_data(r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\LAYING\Subject_2.csv')
accx=data[:,0] #Format data[row, col]
accy=data[:,1]
accz=data[:,2]
axs[0,0].plot(accx,label='accx')
axs[0,0].plot(accy,label='accy')
axs[0,0].plot(accz,label='accz')
axs[0,0].set_title('Laying')
axs[0,0].set_ylabel('Accelerometer value')
axs[0,0].legend()

# Sitting
data=load_data(r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\SITTING\Subject_4.csv')
accx=data[:,0]
accy=data[:,1]
accz=data[:,2]
axs[0,1].plot(accx,label='accx')
axs[0,1].plot(accy,label='accy')
axs[0,1].plot(accz,label='accz')
axs[0,1].set_title('Sitting')
axs[0,1].legend()

# Standing
data = load_data(r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\STANDING\Subject_9.csv')
accx = data[:,0]
accy = data[:,1]
accz = data[:,2]
axs[1,0].plot(accx,label='accx')
axs[1,0].plot(accy,label='accy')
axs[1,0].plot(accz,label='accz')
axs[1,0].set_title('Standing')
axs[1,0].legend()

# Walking
data = load_data(r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\Walking\Subject_10.csv')
accx = data[:,0]
accy = data[:,1]
accz = data[:,2]
axs[1,1].plot(accx,label='accx')
axs[1,1].plot(accy,label='accy')
axs[1,1].plot(accz,label='accz')
axs[1,1].set_title('Walking')
axs[1,1].legend()

# Walking Downstairs
data = load_data(r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\WALKING_DOWNSTAIRS\Subject_12.csv')
accx = data[:,0]
accy = data[:,1]
accz = data[:,2]
axs[2,0].plot(accx,label='accx')
axs[2,0].plot(accy,label='accy')
axs[2,0].plot(accz,label='accz')
axs[2,0].set_title('Walking Downstairs')
axs[2,0].legend()

# Walking Upstairs
data = load_data(r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\WALKING_UPSTAIRS\Subject_13.csv')
accx = data[:,0]
accy = data[:,1]
accz = data[:,2]
axs[2,1].plot(accx,label='accx')
axs[2,1].plot(accy,label='accy')
axs[2,1].plot(accz,label='accz')
axs[2,1].set_title('Walking Upstairs')
axs[2,1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Observations:
#
# Similarities:-
# Laying, Sitting, and Standing show relatively stable and flat readings with minor variations.
# The accx shows the highest values, especially for Standing, while the accy and accz are much lower and relatively constant.
# The flat lines suggest minimal movement, which is consistent with these activities.
#
# Differences:
# Walking, Walking Upstairs, and Walking Downstairs have more dynamic accelerometer readings, with oscillations.
# accx exhibits higher peaks for all three walking activities, indicating significant movement along the x-axis.
# The variations in accy and accz are more in these dynamic activities compared to the static ones, showing the body's motion in multiple directions during walking.
# There are some differences between Walking Upstairs and Walking Downstairs, but the overall pattern of oscillation is similar.
#
# Model:
#
# Static Activities (Laying, Sitting, Standing) can likely be distinguished by a model due to their lower and more stable accelerometer readings.
# Dynamic Activities (Walking, Walking Upstairs, Walking Downstairs) have more complex waves with more variations, which can be differentiated by the model based on the oscillation patterns.
# The differences between static and dynamic activities as well as the subtle differences within each category, shows that a well-trained model should be able to classify these activities based on the accelerometer data.

# %% [markdown]
# -----------------------x---------------------------x----------------------------x---------------------------x-----------------------------x-------------------------------x------------------------x

# %% [markdown]
# Question 2 - Do you think we need a machine learning model to differentiate between static activities (laying, sitting, standing) and dynamic activities(walking, walking_downstairs, walking_upstairs)? Look at the linear acceleration
# $ (\text{accx}^2 + \text{accy}^2 + \text{accz}^2) $
# for each activity and justify your answer. [0.5 marks]

# %%
import numpy as np

def linear_acceleration(accx, accy, accz):
    return (accx**2 + accy**2 + accz**2)

laying = r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\LAYING\Subject_2.csv'
sitting = r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\SITTING\Subject_4.csv'
standing = r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\STANDING\Subject_9.csv'
walking = r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\Walking\Subject_10.csv'
walking_down = r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\WALKING_DOWNSTAIRS\Subject_12.csv'
walking_up = r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\WALKING_UPSTAIRS\Subject_13.csv'

laying_data = np.loadtxt(laying, delimiter=',', skiprows=1, max_rows=500)
sitting_data = np.loadtxt(sitting, delimiter=',', skiprows=1, max_rows=500)
standing_data = np.loadtxt(standing, delimiter=',', skiprows=1, max_rows=500)
walking_data = np.loadtxt(walking, delimiter=',', skiprows=1, max_rows=500)
walking_down_data = np.loadtxt(walking_down, delimiter=',', skiprows=1, max_rows=500)
walking_up_data = np.loadtxt(walking_up, delimiter=',', skiprows=1, max_rows=500)

laying_lin_acc = linear_acceleration(laying_data[:, 0], laying_data[:, 1], laying_data[:, 2])
sitting_lin_acc = linear_acceleration(sitting_data[:, 0], sitting_data[:, 1], sitting_data[:, 2])
standing_lin_acc = linear_acceleration(standing_data[:, 0], standing_data[:, 1], standing_data[:, 2])
walking_lin_acc = linear_acceleration(walking_data[:, 0], walking_data[:, 1], walking_data[:, 2])
walking_down_lin_acc = linear_acceleration(walking_down_data[:, 0], walking_down_data[:, 1], walking_down_data[:, 2])
walking_up_lin_acc = linear_acceleration(walking_up_data[:, 0], walking_up_data[:, 1], walking_up_data[:, 2])

avg_laying = np.mean(laying_lin_acc)
avg_sitting = np.mean(sitting_lin_acc)
avg_standing = np.mean(standing_lin_acc)
avg_walking = np.mean(walking_lin_acc)
avg_walking_down = np.mean(walking_down_lin_acc)
avg_walking_up = np.mean(walking_up_lin_acc)

print("Average Linear Acceleration:")
print(f"Laying: {avg_laying}")
print(f"Sitting: {avg_sitting}")
print(f"Standing: {avg_standing}")
print(f"Walking: {avg_walking}")
print(f"Walking Downstairs: {avg_walking_down}")
print(f"Walking Upstairs: {avg_walking_up}")
# Out:
# Average Linear Acceleration:
# Laying: 1.0111493522820203
# Sitting: 1.0219226842294955
# Standing: 1.0556523404932736
# Walking: 1.178576143015316
# Walking Downstairs: 1.1743810102860834
# Walking Upstairs: 1.1390604155048119

# %% [markdown]
# Observation:
#
# The linear acceleration values for static activities (Laying, Sitting, Standing) are relatively close to each other (ranging from 1.011 to 1.056).
# These values are low compared to dynamic activities, shownig less movement.
#
# The linear acceleration values for dynamic activities (Walking, Walking Downstairs, Walking Upstairs) are higher (ranging from 1.139 to 1.179).
# This shows more significant changes in acceleration due to the movements.
#
# The difference in acceleration values between static and dynamic activities is there but not major.
#
# Human motion can be variable. For example, acceleration while walking can vary based on walking speed. A machine learning model can capture these variations and improve accuracy.

# %% [markdown]
# ------------------------x-----------------------x------------------------x-----------------------------x------------------------------x-------------------------------x-------------------------

# %% [markdown]
# Question 3 - Visualize the data using PCA. [1 marks]

# %% [markdown]
# 3.1 - Use PCA (Principal Component Analysis) on Total Acceleration
# $ (\text{accx}^2 + \text{accy}^2 + \text{accz}^2) $
#  to compress the acceleration timeseries into two features and plot a scatter plot to visualize different class of activities.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd
import seaborn as sns
import tsfel

laying = r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\LAYING\Subject_2.csv'
sitting = r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\SITTING\Subject_4.csv'
standing = r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\STANDING\Subject_9.csv'
walking = r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\Walking\Subject_10.csv'
walking_down = r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\WALKING_DOWNSTAIRS\Subject_12.csv'
walking_up = r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\Combined\Test\WALKING_UPSTAIRS\Subject_20.csv'

#used r to treat backslash as characters and not escape characters

laying_df = pd.read_csv(laying)
sitting_df = pd.read_csv(sitting)
standing_df = pd.read_csv(standing)
walking_df = pd.read_csv(walking)
walking_down_df = pd.read_csv(walking_down)
walking_up_df = pd.read_csv(walking_up)

def total_acc(df):
    df['acc_total'] = (df['accx']**2 + df['accy']**2 + df['accz']**2)
    return df

laying_df = total_acc(laying_df)
sitting_df = total_acc(sitting_df)
standing_df = total_acc(standing_df)
walking_df = total_acc(walking_df)
walking_down_df = total_acc(walking_down_df)
walking_up_df = total_acc(walking_up_df)

laying_df['Label'] = 6 #each line adds a new column to df called Label
sitting_df['Label'] = 4
standing_df['Label'] = 5
walking_df['Label'] = 1
walking_down_df['Label'] = 3
walking_up_df['Label'] = 2 

combined_df = pd.concat([laying_df, sitting_df, standing_df, walking_df, walking_down_df, walking_up_df], ignore_index=True) #resets index and make one df with all values
print(combined_df)
pca_dataframe = pd.DataFrame()
classes = {"WALKING": 1, "WALKING_UPSTAIRS": 2, "WALKING_DOWNSTAIRS": 3, "SITTING": 4, "STANDING": 5, "LAYING": 6}

for label in tuple(classes.values()): #Iterates through labels
    subset = combined_df[combined_df["Label"] == label]["acc_total"].values #selects total acc from particular label
    subset = subset[:len(subset) - (len(subset) % 500)] #ensuring data is in multplles of 500
    subset = subset.reshape(-1, 500)
    pca = PCA(n_components=2)
    pca_result = pca.fit_transform(subset) #applies pca and reduces dimentionality into 2 constraints
    pca_df = pd.DataFrame(data=pca_result, columns=["PCA1", "PCA2"])
    pca_df["Label"] = label #labels added to new dataframe
    pca_dataframe = pd.concat([pca_dataframe, pca_df], ignore_index=True)

label_mapping = {1: "WALKING", 2: "WALKING_UPSTAIRS", 3: "WALKING_DOWNSTAIRS", 4: "SITTING", 5: "STANDING", 6: "LAYING"} #Maps from label to activity
pca_dataframe["Activity"] = pca_dataframe["Label"].map(label_mapping) #creates new column activity

sns.set(style="whitegrid") #background style of white grid
plt.figure(figsize=(19, 9))
sns.scatterplot(x="PCA1", y="PCA2", hue="Activity", data=pca_dataframe, s=300, palette="tab10") #Hue colors points according to activity. 300 size
plt.title("PCA Scatter Plot for Total Acceleration", fontweight='bold', fontsize=20)
plt.xlabel("PCA 1", fontweight='bold', fontsize=20)
plt.ylabel("PCA 2", fontweight='bold', fontsize=20)
plt.legend(title="Activities")
plt.show()
# Out:
#            accx      accy      accz  acc_total  Label
# 0     -0.185673  0.737995  0.663749   1.019674      6
# 1     -0.181578  0.730275  0.661433   1.003766      6
# 2     -0.177545  0.726232  0.664359   1.000309      6
# 3     -0.177920  0.724708  0.672195   1.008703      6
# 4     -0.174591  0.717580  0.681756   1.010195      6
# ...         ...       ...       ...        ...    ...
# 18747  1.316438 -0.593719 -0.024990   2.086136      2
# 18748  1.335946 -0.614238 -0.061097   2.165773      2
# 18749  1.341376 -0.639749 -0.133876   2.226491      2
# 18750  1.340405 -0.672009 -0.222105   2.297613      2
# 18751  1.319803 -0.690698 -0.204273   2.260671      2
#
# [18752 rows x 5 columns]

# %% [markdown]
# -------------x----------------------x-------------------x------------------------x----------------------x

# %% [markdown]
# 3.2 - Next, use TSFEL (a featurizer library) to create features (your choice which ones you feel are useful) and then perform PCA to obtain two features. Plot a scatter plot to visualize different class of activities.

# %%
X = combined_df[['accx', 'accy', 'accz']] #all data
y = combined_df['Label'] #activity labels

cfg_file = tsfel.get_features_by_domain("statistical") #tsfel config file for statistical features domain
selected_features = {
    'statistical': {
        'root_mean_square': cfg_file['statistical']['Root mean square'],
        'Std': cfg_file['statistical']['Standard deviation'],
        'Mean': cfg_file['statistical']['Mean'],
        'ECDF': cfg_file['statistical']['ECDF'] #Empirical Cumulative Distribution Function
    }
}

X_tsfel = tsfel.time_series_features_extractor(selected_features, X, window_size=500, verbose=0) # 500 samples from each window. Verbose doesnt give output messages
 
num_windows = X_tsfel.shape[0] #no of windows (rows) in x_tsfel
X_tsfel["Label"] = y.iloc[::500][:num_windows].values #every 500th label to match window size

pca = PCA(n_components=2)
pca_tsfel = pca.fit_transform(X_tsfel.iloc[:, :-1]) #select all columns except the last one(label)
pca_tsfel_df = pd.DataFrame(data=pca_tsfel, columns=["PCA_1", "PCA_2"])
pca_tsfel_df["Label"] = X_tsfel["Label"] #adds another column with labels

label_map = {1: "WALKING", 2: "WALKING_UPSTAIRS", 3: "WALKING_DOWNSTAIRS", 4: "SITTING", 5: "STANDING", 6: "LAYING"}
pca_tsfel_df["Activity"] = pca_tsfel_df["Label"].map(label_map) #map labels

sns.set(style="whitegrid")
plt.figure(figsize=(19, 9))
sns.scatterplot(x="PCA_1", y="PCA_2", hue="Activity", data=pca_tsfel_df, s=300, palette="tab10")
plt.title("PCA Scatter Plot for Selected TSFEL Features", fontweight='bold', fontsize=20)
plt.xlabel("PCA 1", fontweight='bold', fontsize=20)
plt.ylabel("PCA 2", fontweight='bold', fontsize=20)
plt.legend(title="Activities")
plt.show()
# Out:
# C:\Users\Vansh\AppData\Local\Temp\ipykernel_14052\2546526341.py:14: UserWarning: Using default sampling frequency set in configuration file.
#   X_tsfel = tsfel.time_series_features_extractor(selected_features, X, window_size=500, verbose=0)
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='37',
#                   style='width: 25%',
#               >
#                   0
#               </progress>

# %% [markdown]
# ----------------------------x-------------------------x-------------------------------x----------------------------x

# %% [markdown]
# 3.3 - Now use the features provided by the dataset and perform PCA to obtain two features. Plot a scatter plot to visualize different class of activities.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import seaborn as sns

body_acc_x_train=r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\UCI HAR Dataset\train\Inertial Signals\body_acc_x_train.txt'
body_acc_y_train=r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\UCI HAR Dataset\train\Inertial Signals\body_acc_y_train.txt'
body_acc_z_train=r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\UCI HAR Dataset\train\Inertial Signals\body_acc_z_train.txt'

body_gyro_x_train=r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\UCI HAR Dataset\train\Inertial Signals\body_gyro_x_train.txt'
body_gyro_y_train=r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\UCI HAR Dataset\train\Inertial Signals\body_gyro_y_train.txt'
body_gyro_z_train=r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\UCI HAR Dataset\train\Inertial Signals\body_gyro_z_train.txt'

y_train_path=r'C:\Users\Vansh\Desktop\Coding\ML\Assignment 1\Task 1\UCI HAR Dataset\train\y_train.txt'
y_train=pd.read_csv(y_train_path, header=None, delim_whitespace=True) #labels

def load_data(file_path):
    return pd.read_csv(file_path, delim_whitespace=True, header=None)

bod_x=load_data(body_acc_x_train)
bod_y=load_data(body_acc_y_train)
bod_z=load_data(body_acc_z_train)

gyro_x=load_data(body_gyro_x_train)
gyro_y=load_data(body_gyro_y_train)
gyro_z=load_data(body_gyro_z_train)

features = pd.concat([bod_x,bod_y,bod_z,gyro_x,gyro_y,gyro_z], axis=1)
pca = PCA(n_components=2)
pca_result = pca.fit_transform(features) #fits pca model on features
pca_df = pd.DataFrame(data=pca_result, columns=["PCA_1","PCA_2"])

pca_df["Label"] = y_train.values.flatten()
label_map = {1:"WALKING", 2:"WALKING_UPSTAIRS", 3:"WALKING_DOWNSTAIRS", 4:"SITTING", 5:"STANDING", 6:"LAYING"}
pca_df["Activity"] = pca_df["Label"].map(label_map)

sns.set(style="whitegrid")
plt.figure(figsize=(19, 9))
sns.scatterplot(x="PCA_1", y="PCA_2", hue="Activity", data=pca_df, s=300, palette="tab10")
plt.title("PCA Scatter Plot for Provided Features", fontweight='bold', fontsize=20)
plt.xlabel("PCA 1", fontweight='bold', fontsize=20)
plt.ylabel("PCA 2", fontweight='bold', fontsize=20)
plt.legend(title="Activities")
plt.show()
# Out:
# C:\Users\Vansh\AppData\Local\Temp\ipykernel_14052\398039542.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   y_train=pd.read_csv(y_train_path, header=None, delim_whitespace=True) #labels
# C:\Users\Vansh\AppData\Local\Temp\ipykernel_14052\398039542.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   return pd.read_csv(file_path, delim_whitespace=True, header=None)
# C:\Users\Vansh\AppData\Local\Temp\ipykernel_14052\398039542.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   return pd.read_csv(file_path, delim_whitespace=True, header=None)
# ...

# %% [markdown]
# **3.4** - Compare the results of PCA on Total Acceleration, TSFEL and the dataset features. Which method do you think is better for visualizing the data?
#
# **Total Acceleration:**
# The points on the graph are spread out and don't form clear groups. This means it's hard to tell the activities apart because some of them overlap.
#
# **TSFEL Features:**
# The points are more spread out, and some activities are easier to tell apart but not perfectly. The features created by TSFEL make it easier to see differences between activities.
#
# **Provided Features:**
# The points are crowded together, with a lot of overlap between activities. This makes it hard to separate the different activities.
#
# **TSFEL Features** do the best job of showing differences between activities. While it's not perfect, it's easier to see which points belong to which activity compared to the other methods. If we want to clearly see and separate the activities on a graph, the features created by TSFEL work the best.

# %% [markdown]
# ----------------x--------------------x--------------------x----------------------x------------------x---------------x---

# %% [markdown]
# Question 4 - Calculate the correlation matrix of the features obtained by TSFEL and provided in the dataset. Identify the features that are highly correlated with each other. Are there any redundant features? [1 marks]

# %%
corr_tsfel = X_tsfel.corr()
print("Correlation Matrix for TSFEL Features:")
print(corr_tsfel)

high_corr_tsfel = corr_tsfel[abs(corr_tsfel) > 0.8]
print("Highly Correlated Features (TSFEL):")
print(high_corr_tsfel)



corr_provided = features.corr()
print("Correlation Matrix for Provided Features:")
print(corr_provided)

highly_corr_provided = corr_provided[abs(corr_provided) > 0.8]
print("Highly Correlated Features (Provided):")
print(highly_corr_provided)
# Out:
# Correlation Matrix for TSFEL Features:
#                        accx_ECDF_0  accx_ECDF_1  accx_ECDF_2  accx_ECDF_3  \
# accx_ECDF_0                    NaN          NaN          NaN          NaN
# accx_ECDF_1                    NaN          NaN          NaN          NaN
# accx_ECDF_2                    NaN          NaN          NaN          NaN
# accx_ECDF_3                    NaN          NaN          NaN          NaN
# accx_ECDF_4                    NaN          NaN          NaN          NaN
# accx_ECDF_5                    NaN          NaN          NaN          NaN
# accx_ECDF_6                    NaN          NaN          NaN          NaN
# accx_ECDF_7                    NaN          NaN          NaN          NaN
# accx_ECDF_8                    NaN          NaN          NaN          NaN
# accx_ECDF_9                    NaN          NaN          NaN          NaN
# accx_Mean                      NaN          NaN          NaN          NaN
# ...

# %% [markdown]
# Observation:
#
# 1. **TSFEL Features:**
#
# High Correlations:
# accx_Absolute energy and accx_Area under the curve: Correlation = 0.986
# accx_Average power and accx_Area under the curve: Correlation = 0.986
# accx_Average power and accx_Absolute energy: Correlation = 1.000
#
# Since accx_Absolute energy and accx_Area under the curve are almost perfectly correlated (0.986), they are conveying very similar information. We can choose to keep just one of these features to simplify the model.
#
# accx_Average power is perfectly correlated with accx_Absolute energy (1.000), which means accx_Average power contains the same information as accx_Absolute energy. Hence, including both might not add new information to the model.
#
# accx_Absolute energy, accx_Area under the curve is highly correlated with accx_Average power and accx_Absolute energy. Including both can lead to redundancy because these features are providing very similar data.
#
# accx_Average power is perfectly correlated with accx_Absolute energy (1.000), so including both is redundant.
#
# accx_ECDF Percentile_0 and accx_ECDF Percentile_1 are highly correlated. Including both may not be necessary as they provide similar percentile information. We can consider one.
#
# All the NaN correlations can be removed dueto lack of information.
#
# 1. **Provided Features:**
#
# High Correlations:
# Feature_0 and Feature_1: Correlation = 0.907
# Feature_1 and Feature_2: Correlation = 0.907
# Feature_2 and Feature_3: Correlation = 0.912
# Feature_3 and Feature_4: Correlation = 0.905
# Feature_4 and Feature_5: Correlation = 0.910
# Feature_5 and Feature_6: Correlation = 0.716
#
# Since Feature_0 is highly correlated with Feature_1, including both may result in redundancy.
#
# Feature_1 is highly correlated with Feature_0 and Feature_2. If we include all three, the information from Feature_1 might overlap significantly with the others, causing redundancy.
#
# Feature_2 is highly correlated with Feature_1 and Feature_3. Including all these might lead to redundant information. Consider removing one of these to reduce redundancy.
#
# Feature_4 is highly correlated with Feature_3 and Feature_5. Including all these features can lead to redundancy. We can consider keeping only one of these highly correlated features.
#
# Feature_5 is highly correlated with Feature_4, but less so with Feature_6. Including both Feature_4 and Feature_5 might be redundant. We might retain the feature that provides the most unique information.
#
# Feature_6 is less correlated with other features compared to others. Its lower correlation might suggest it adds less overlap with other features.
